# %% [markdown]
# <a href="https://colab.research.google.com/github/revs1/Simple_ML_notebooks-revs96/blob/master/Timbrenet_Execution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Github Projects
# Out:
# /content/drive/My Drive/Colab Notebooks/Github Projects

# %%
! git clone https://github.com/CreativAI-UC/TimbreNet
# Out:
# Cloning into 'TimbreNet'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1126 (delta 0), reused 2 (delta 0), pack-reused 1123
# Receiving objects: 100% (1126/1126), 280.89 MiB | 17.42 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Checking out files: 100% (497/497), done.

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Github Projects/TimbreNet
# Out:
# /content/drive/My Drive/Colab Notebooks/Github Projects/TimbreNet

# %%
# !python timbrenet_generate_chord.py
# Out:
# 2020-05-15 08:23:39.164196: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-15 08:23:41.033111: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-15 08:23:41.081991: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:23:41.082659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-05-15 08:23:41.082711: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python timbrenet_generate_latent_map.py
# Out:
# 2020-05-15 08:39:42.086931: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-05-15 08:39:44.350220: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-15 08:39:44.376785: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-05-15 08:39:44.377453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P4 computeCapability: 6.1
# coreClock: 1.1135GHz coreCount: 20 deviceMemorySize: 7.43GiB deviceMemoryBandwidth: 178.99GiB/s
# 2020-05-15 08:39:44.377491: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
